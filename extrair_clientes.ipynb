# %% [markdown]
# # Estrutura da Página HTML para RPA
#
# ## Link (GitHub Pages)
#
# https://digitalinnovationone.github.io/dio-lab-assistente-investimentos-rpa-n8n
#
# ## Código HTML
#
# ```html
# <!doctype html>
# <html lang="pt-br">
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1" />
#   <title>Clientes</title>
#   <style>
#     body { font-family: Arial, sans-serif; margin: 24px; }
#     table { border-collapse: collapse; width: 100%; max-width: 900px; }
#     th, td { border: 1px solid #ddd; padding: 10px; text-align: left; }
#     th { background: #f5f5f5; }
#   </style>
# </head>
# <body>
#   <h1>Lista de Clientes</h1>
#
#   <table id="clientes">
#     <thead>
#       <tr>
#         <th>Nome</th>
#         <th>Email</th>
#         <th>Saldo</th>
#         <th>Perfil</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td class="nome">Ana Silva</td>
#         <td class="email">ana@email.com</td>
#         <td class="saldo">R$ 12.500,00</td>
#         <td class="perfil">Conservador</td>
#       </tr>
#       <tr>
#         <td class="nome">Bruno Lima</td>
#         <td class="email">bruno@email.com</td>
#         <td class="saldo">R$ 3.200,00</td>
#         <td class="perfil">Moderado</td>
#       </tr>
#       <tr>
#         <td class="nome">Carla Souza</td>
#         <td class="email">carla@email.com</td>
#         <td class="saldo">R$ 28.900,00</td>
#         <td class="perfil">Arrojado</td>
#       </tr>
#     </tbody>
#   </table>
# </body>
# </html>
# ```

# %% [markdown]
# # Dependências (Python)

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests) (2026.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4) (4.16.0)

# %% [markdown]
# # Código-fonte RPA (Pyhton)

# %%
import requests
from bs4 import BeautifulSoup

URL_PAGINA = "https://digitalinnovationone.github.io/dio-lab-assistente-investimentos-rpa-n8n/"
N8N_WEBHOOK = "https://n8n.fryctoria.com.br/webhook-test/Clientes"

# 1) Baixar a página
html = requests.get(URL_PAGINA).text

# 2) Ler a tabela de clientes
soup = BeautifulSoup(html, "html.parser")
linhas = soup.select("#clientes tbody tr")
clientes = []
for linha in linhas:
    colunas = linha.find_all("td")
    cliente = {
        "nome": colunas[0].get_text(strip=True),
        "email": colunas[1].get_text(strip=True),
        "saldo": colunas[2].get_text(strip=True),
        "perfil": colunas[3].get_text(strip=True),
    }
    clientes.append(cliente)
print("Clientes encontrados:", len(clientes))
print("Exemplo 1º cliente:", clientes[0] if clientes else "nenhum")
# 3) Enviar pro n8n
payload = {"clientes": clientes}
resp = requests.post(
    N8N_WEBHOOK,
    json=payload,
    headers={"Content-Type": "application/json"},
    timeout=60
)
print("Status:", resp.status_code)
print("Headers:", dict(resp.headers))
print("Resposta (primeiros 1500 chars):")
print(resp.text[:1500])
# Out:
# Clientes encontrados: 10
# Exemplo 1º cliente: {'nome': 'Ana Silva', 'email': 'ana@email.com', 'saldo': 'R$ 12.500,00', 'perfil': 'Conservador'}
# Status: 200
# Headers: {'Alt-Svc': 'h3=":443"; ma=2592000', 'Content-Security-Policy': 'sandbox allow-downloads allow-forms allow-modals allow-orientation-lock allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-presentation allow-scripts allow-top-navigation-by-user-activation allow-top-navigation-to-custom-protocols', 'Content-Type': 'application/json; charset=utf-8', 'Date': 'Wed, 16 Sep 2026 22:18:35 GMT', 'Vary': 'Accept-Encoding', 'Via': '1.1 Caddy', 'Transfer-Encoding': 'chunked'}
# Resposta (primeiros 1500 chars):
